# %%
import pandas as pd
import shutil
import os
import numpy as np

# %% [markdown]
# Combine metadatas

# %%
def combine_metadata(metadata1_filename, metadata2_filename):
    combined = pd.concat([pd.read_csv(metadata1_filename), pd.read_csv(metadata2_filename)])
    lesions = combined['meta.clinical.diagnosis'].unique()
    print('Lesions on this dataset: ', lesions)
    combined.drop_duplicates(inplace=True)
    return combined

# %%
SOURCE_DATA_PATH = '../datasets/raw/ISIC/'

# %%
metadata = combine_metadata(metadata1_filename=SOURCE_DATA_PATH + 'metadata1.csv',
                 metadata2_filename=SOURCE_DATA_PATH +'metadata2.csv')

metadata.head()
# Out:
# Lesions on this dataset:  ['nevus' 'melanoma' 'solar lentigo' 'actinic keratosis' 'vascular lesion'
#  'seborrheic keratosis' 'lentigo NOS']
#                         _id          name  meta.clinical.age_approx  \
# 0  5c95461adb6d7c19d0bc1319  ISIC_0057321                      10.0
# 1  5c95461adb6d7c19d0bc131c  ISIC_0057324                      45.0
# 2  5c95461bdb6d7c19d0bc1345  ISIC_0057365                      70.0
# 3  5c954624db6d7c19d0bc1445  ISIC_0057621                      55.0
# 4  5c954626db6d7c19d0bc1487  ISIC_0057687                      60.0
#
#   meta.clinical.anatom_site_general meta.clinical.benign_malignant  \
# 0                       palms/soles                         benign
# 1                       palms/soles                      malignant
# 2                       palms/soles                         benign
# 3                       palms/soles                      malignant
# 4                       palms/soles                      malignant
#
#    meta.clinical.clin_size_long_diam_mm meta.clinical.diagnosis  \
# 0                                   NaN                   nevus
# 1                                   NaN                melanoma
# 2                                   NaN                   nevus
# 3                                   NaN                melanoma
# 4                                   NaN                melanoma
#
#   meta.clinical.diagnosis_confirm_type meta.clinical.family_hx_mm  \
# 0                                  NaN                        NaN
# 1                       histopathology                        NaN
# 2                       histopathology                        NaN
# 3                       histopathology                        NaN
# 4                       histopathology                        NaN
#
#   meta.clinical.lesion_id  ...  meta.clinical.sex  \
# 0                     NaN  ...               male
# 1                     NaN  ...               male
# 2                     NaN  ...             female
# 3                     NaN  ...             female
# 4                     NaN  ...               male
#
#    meta.acquisition.acquisition_day  meta.acquisition.blurry  \
# 0                               NaN                      NaN
# 1                               NaN                      NaN
# 2                               NaN                      NaN
# 3                               NaN                      NaN
# 4                               NaN                      NaN
#
#    meta.acquisition.color_tint  meta.acquisition.dermoscopic_type  \
# 0                          NaN                                NaN
# 1                          NaN                                NaN
# 2                          NaN                                NaN
# 3                          NaN                                NaN
# 4                          NaN                                NaN
#
#    meta.acquisition.hairy meta.acquisition.image_type  \
# 0                     NaN                         NaN
# 1                     NaN                         NaN
# 2                     NaN                         NaN
# 3                     NaN                         NaN
# 4                     NaN                         NaN
#
#   meta.acquisition.marker_pen meta.acquisition.pixelsX  \
# 0                         NaN                     1024
# 1                         NaN                     1024
# 2                         NaN                     1024
# 3                         NaN                     1024
# 4                         NaN                     1024
#
#   meta.acquisition.pixelsY
# 0                     1024
# 1                     1024
# 2                     1024
# 3                     1024
# 4                     1024
#
# [5 rows x 29 columns]

# %% [markdown]
# Remove lesions used for training the model

# %%
df_train = pd.read_csv(SOURCE_DATA_PATH + 'train_split_1.csv')

# %%
print('Number of acral images used for training: ', df_train[df_train.image.isin(metadata.name)].shape[0])
# Out:
# Number of acral images used for training:  251

# %%
test_isic = metadata[~metadata.name.isin(df_train.image)]
metadata = test_isic
print('Total of acral images for testing: ', test_isic.shape[0])
# Out:
# Total of acral images for testing:  149

# %%
melanoma_imgs = test_isic[test_isic['meta.clinical.diagnosis'] == 'melanoma']
benign_imgs = test_isic[test_isic['meta.clinical.diagnosis'] != 'melanoma']

# %%
print('Total of MELANOMA images for testing: ', melanoma_imgs.shape[0])
print('Total of BENIGN images for testing: ', benign_imgs.shape[0])
# Out:
# Total of MELANOMA images for testing:  72
# Total of BENIGN images for testing:  77

# %% [markdown]
# Save filtered images and metadata

# %%
datasets_isic = ['MSK-1',
                'ISIC 2020 Challenge - MSKCC contribution',
                'BCN_20000',
                'UDA-2',
                'UDA-1',
                'MSK-4',
                'MSK-2',
                'BCN_2020_Challenge',
                'HAM10000']

# %%
melanoma_img_filenames = [str(img) + '.jpg' for img in melanoma_imgs.name]
benign_img_filenames = [str(img) + '.jpg' for img in benign_imgs.name]

# %%
DESTINATION_DATASET_PATH = '../datasets/processed/ISIC/'

if not os.path.exists(DESTINATION_DATASET_PATH):

    # if the demo_folder directory is not present
    # then create it
    os.makedirs(DESTINATION_DATASET_PATH, exist_ok=True)

# %%
if not os.path.exists(DESTINATION_DATASET_PATH + 'melanoma'):

    # if the demo_folder directory is not present
    # then create it
    os.makedirs(DESTINATION_DATASET_PATH + 'melanoma', exist_ok=True)

if not os.path.exists(DESTINATION_DATASET_PATH + 'benign'):

    # if the demo_folder directory is not present
    # then create it
    os.makedirs(DESTINATION_DATASET_PATH + 'benign', exist_ok=True)

# %%
for dataset in datasets_isic:
    dir_files = os.listdir(SOURCE_DATA_PATH + dataset)
#     print(len(dir_files))
    images_dir = [file for file in dir_files if file.lower().endswith(('.png', '.jpg', '.jpeg', '.tiff', '.bmp'))]
#     print(len(images_dir))
#     print(images_dir)
    for img in images_dir:
        # print(img)
        if img in melanoma_img_filenames:
            filename = (DESTINATION_DATASET_PATH + 'melanoma/' + img)
            shutil.copy(SOURCE_DATA_PATH + dataset +'/'+img, DESTINATION_DATASET_PATH + 'melanoma/')
        elif img in benign_img_filenames:
            filename = (DESTINATION_DATASET_PATH + 'benign/' + img)
            shutil.copy(SOURCE_DATA_PATH + dataset +'/'+img, DESTINATION_DATASET_PATH + 'benign/')
        
        metadata.loc[metadata.name == img.split('.')[0], 'lesion_filename'] = filename[3:]

# %%
metadata['label'] = metadata['meta.clinical.diagnosis'].apply(lambda x: 1 if x == 'melanoma' else 0)
metadata['is_dermoscopic'] = True

# %%
metadata.to_csv(DESTINATION_DATASET_PATH + 'metadata.csv', index=False)

# %%
metadata
# Out:
#                          _id          name  meta.clinical.age_approx  \
# 2   5c95461bdb6d7c19d0bc1345  ISIC_0057365                      70.0
# 4   5c954626db6d7c19d0bc1487  ISIC_0057687                      60.0
# 6   5c95462adb6d7c19d0bc1509  ISIC_0057817                      75.0
# 7   5c95462cdb6d7c19d0bc1549  ISIC_0057881                      55.0
# 15  5c954637db6d7c19d0bc1692  ISIC_0058210                      25.0
# ..                       ...           ...                       ...
# 86  5c954602db6d7c19d0bc1094  ISIC_0056676                      45.0
# 88  5c954604db6d7c19d0bc10c8  ISIC_0056728                      70.0
# 90  5c954609db6d7c19d0bc1157  ISIC_0056871                      70.0
# 91  5c95460ddb6d7c19d0bc11ad  ISIC_0056957                      85.0
# 96  5c954612db6d7c19d0bc123a  ISIC_0057098                      80.0
#
#    meta.clinical.anatom_site_general meta.clinical.benign_malignant  \
# 2                        palms/soles                         benign
# 4                        palms/soles                      malignant
# 6                        palms/soles                         benign
# 7                        palms/soles                      malignant
# 15                       palms/soles                         benign
# ..                               ...                            ...
# 86                       palms/soles                      malignant
# 88                       palms/soles                      malignant
# 90                       palms/soles                      malignant
# 91                       palms/soles                      malignant
# 96                       palms/soles                            NaN
#
#     meta.clinical.clin_size_long_diam_mm meta.clinical.diagnosis  \
# 2                                    NaN                   nevus
# 4                                    NaN                melanoma
# 6                                    NaN                   nevus
# 7                                    NaN                melanoma
# 15                                   NaN                   nevus
# ..                                   ...                     ...
# 86                                   NaN                melanoma
# 88                                   NaN                melanoma
# 90                                   NaN                melanoma
# 91                                   NaN                melanoma
# 96                                   NaN    seborrheic keratosis
#
#              meta.clinical.diagnosis_confirm_type meta.clinical.family_hx_mm  \
# 2                                  histopathology                        NaN
# 4                                  histopathology                        NaN
# 6                                  histopathology                        NaN
# 7                                  histopathology                        NaN
# 15                                            NaN                        NaN
# ..                                            ...                        ...
# 86                                 histopathology                        NaN
# 88                                 histopathology                        NaN
# 90                                 histopathology                        NaN
# 91                                 histopathology                        NaN
# 96  confocal microscopy with consensus dermoscopy                        NaN
#
#    meta.clinical.lesion_id  ...  meta.acquisition.color_tint  \
# 2                      NaN  ...                          NaN
# 4                      NaN  ...                          NaN
# 6                      NaN  ...                          NaN
# 7                      NaN  ...                          NaN
# 15                     NaN  ...                          NaN
# ..                     ...  ...                          ...
# 86                     NaN  ...                          NaN
# 88                     NaN  ...                          NaN
# 90                     NaN  ...                          NaN
# 91                     NaN  ...                          NaN
# 96                     NaN  ...                          NaN
#
#     meta.acquisition.dermoscopic_type  meta.acquisition.hairy  \
# 2                                 NaN                     NaN
# 4                                 NaN                     NaN
# 6                                 NaN                     NaN
# 7                                 NaN                     NaN
# 15                                NaN                     NaN
# ..                                ...                     ...
# 86                                NaN                     NaN
# 88                                NaN                     NaN
# 90                                NaN                     NaN
# 91                                NaN                     NaN
# 96                                NaN                     NaN
#
#     meta.acquisition.image_type  meta.acquisition.marker_pen  \
# 2                           NaN                          NaN
# 4                           NaN                          NaN
# 6                           NaN                          NaN
# 7                           NaN                          NaN
# 15                          NaN                          NaN
# ..                          ...                          ...
# 86                          NaN                          NaN
# 88                          NaN                          NaN
# 90                          NaN                          NaN
# 91                          NaN                          NaN
# 96                          NaN                          NaN
#
#     meta.acquisition.pixelsX meta.acquisition.pixelsY  \
# 2                       1024                     1024
# 4                       1024                     1024
# 6                       1024                     1024
# 7                       1024                     1024
# 15                      1024                     1024
# ..                       ...                      ...
# 86                      1024                     1024
# 88                      1024                     1024
# 90                      1024                     1024
# 91                      1024                     1024
# 96                      1024                     1024
#
#                                       lesion_filename label is_dermoscopic
# 2     datasets/processed/ISIC/benign/ISIC_0057365.jpg     0           True
# 4   datasets/processed/ISIC/melanoma/ISIC_0057687.jpg     1           True
# 6     datasets/processed/ISIC/benign/ISIC_0057817.jpg     0           True
# 7   datasets/processed/ISIC/melanoma/ISIC_0057881.jpg     1           True
# 15    datasets/processed/ISIC/benign/ISIC_0058210.jpg     0           True
# ..                                                ...   ...            ...
# 86  datasets/processed/ISIC/melanoma/ISIC_0056676.jpg     1           True
# 88  datasets/processed/ISIC/melanoma/ISIC_0056728.jpg     1           True
# 90  datasets/processed/ISIC/melanoma/ISIC_0056871.jpg     1           True
# 91  datasets/processed/ISIC/melanoma/ISIC_0056957.jpg     1           True
# 96    datasets/processed/ISIC/benign/ISIC_0057098.jpg     0           True
#
# [149 rows x 32 columns]

# %%
metadata.lesion_filename
# Out:
# 2       datasets/processed/ISIC/benign/ISIC_0057365.jpg
# 4     datasets/processed/ISIC/melanoma/ISIC_0057687.jpg
# 6       datasets/processed/ISIC/benign/ISIC_0057817.jpg
# 7     datasets/processed/ISIC/melanoma/ISIC_0057881.jpg
# 15      datasets/processed/ISIC/benign/ISIC_0058210.jpg
#                             ...
# 86    datasets/processed/ISIC/melanoma/ISIC_0056676.jpg
# 88    datasets/processed/ISIC/melanoma/ISIC_0056728.jpg
# 90    datasets/processed/ISIC/melanoma/ISIC_0056871.jpg
# 91    datasets/processed/ISIC/melanoma/ISIC_0056957.jpg
# 96      datasets/processed/ISIC/benign/ISIC_0057098.jpg
# Name: lesion_filename, Length: 149, dtype: object
